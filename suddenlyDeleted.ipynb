# %%
import requests
import urllib.request as urllib2
from bs4 import BeautifulSoup
import csv
from datetime import datetime
import pandas as pd
import numpy as np

# %%
product_list = pd.read_excel("product_list_v03.xlsx", sheet_name="unique_keys")

# %%
key = []
headers ={"User-Agent": 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36'}

for i in product_list["unique_keywords"]:
    key.append(i)
keywords = [y for x in key for y in x.split(',')]

# %%
nothing = [""]
df = pd.DataFrame({"Date of process":nothing,"Products ":nothing,"Prices ":nothing,"Adress ":nothing,"Keyword ":nothing})
df.to_csv("data.csv",index=False)
print("Csv file for saving data is created!")
# Out:
# Csv file for saving data is created!

# %%
for key in keywords:
    if ' ' in key:
        key = key.replace(' ', '')
    else:
        key = key
    URL = "https://makromarket.uz/search?term={}".format(key)
    page = requests.get(URL, headers=headers)
    soup = BeautifulSoup(page.content,'html.parser')
    titles = []
    prices = []
    Urls = []
    product_title = soup.find_all(attrs={"class":"goods-item-name"})
    product_price = soup.find_all(attrs={"class":"card-new-price"})
    product_url = soup.find_all(attrs={"class":"goods-item-img-wrapper"})
    titles = [x.get_text() for x in product_title] #getting all titles in the list
    prices = [y.get_text() for y in product_price] #getting all prices in the list
    Urls = [z.get("href") for z in product_url]#getting all product urls in the list
    
    try:
        with open('data.csv', 'a', newline='', encoding='cp1251') as thething:
            writer = csv.writer(thething)
            for index,title in enumerate(titles):
                writer.writerow([datetime.now(),title,prices[index],URL,key,Urls[index]])
        print("{}'s fineshed processing".format(key)) 
    except UnicodeEncodeError:
        continue
    
    
print(len(keywords)," product informations in Makromarket.uz are exported to data.csv successfully!!!")
# Out:
# Мука's fineshed processing
# Лепешка's fineshed processing
# Хлеб's fineshed processing
# Выпечка's fineshed processing
# макароны's fineshed processing
# Вермишель's fineshed processing
# Рис's fineshed processing
# Крупа's fineshed processing
# Гречка's fineshed processing
# Перловка's fineshed processing
# Пшено's fineshed processing
# овсянка's fineshed processing
# Горох's fineshed processing
# Фасоль's fineshed processing
# Маш's fineshed processing
# Говядина's fineshed processing
# фарш's fineshed processing
# печень's fineshed processing
# Баранина's fineshed processing
# Свинина's fineshed processing
# птицы's fineshed processing
# Голень's fineshed processing
# окорочка's fineshed processing
# Колбаса's fineshed processing
# Сосиски's fineshed processing
# сардельки's fineshed processing
# Ветчина's fineshed processing
# консервы's fineshed processing
# Пельмени's fineshed processing
# Рыба's fineshed processing
# Молоко's fineshed processing
# Кефир's fineshed processing
# простокваша's fineshed processing
# Сметана's fineshed processing
# Сливки's fineshed processing
# Творог's fineshed processing
# Сузьма's fineshed processing
# Сыр's fineshed processing
# Мороженое's fineshed processing
# Йогурт's fineshed processing
# смесь's fineshed processing
# Яйцо's fineshed processing
# Масло's fineshed processing
# Маргарин's fineshed processing
# жиры's fineshed processing
# Яблоки's fineshed processing
# Груша's fineshed processing
# Банан's fineshed processing
# Виноград's fineshed processing
# Цитрусовые's fineshed processing
# Сумка's fineshed processing
# бритва's fineshed processing
# Щетка%20зубная's fineshed processing
# Портфель's fineshed processing
# Чемоданы's fineshed processing
# Галстук's fineshed processing
# ремни's fineshed processing
# Зонт's fineshed processing
# Нитки's fineshed processing
# Обручальное+кольцо's fineshed processing
# Ботинки's fineshed processing
# полуботинки's fineshed processing
# Сапоги's fineshed processing
# Кроссовки's fineshed processing
# Туфли's fineshed processing
# Босоножки's fineshed processing
# сандалии's fineshed processing
# Домашняя+обувь's fineshed processing
# Галоши's fineshed processing
# Кирпич's fineshed processing
# Обои's fineshed processing
# Доски's fineshed processing
# Краски's fineshed processing
# Шифер's fineshed processing
# Стекло's fineshed processing
# профил's fineshed processing
# Цемент's fineshed processing
# Шпатлевка's fineshed processing
# Линолеум's fineshed processing
# Плитка's fineshed processing
# Стол's fineshed processing
# Мебель's fineshed processing
# Мебель+кухни's fineshed processing
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-5-d8236b0ec1f8> in <module>
#      18
#      19     try:
# ---> 20         with open('data.csv', 'a', newline='', encoding='cp1251') as thething:
#      21             writer = csv.writer(thething)
#      22             for index,title in enumerate(titles):
#
# PermissionError: [Errno 13] Permission denied: 'data.csv'

# %%
for key in keywords:
    if ' ' in key:
        key = key.replace(' ', '')
    else:
        key = key
        
    URL = "http://hm.uz/search/?query={}".format(key)
    page = requests.get(URL, headers=headers)
    soup = BeautifulSoup(page.content,'html.parser')
    
    title = soup.find_all(attrs={"item__title"})
    price = soup.find_all(attrs={"item__prc-w"})
    url = soup.find_all(attrs={"item__image item__image_gv"})
    titles = [x.get_text() for x in title]
    prices = [y.get_text() for y in price]
    Urls = [z.get('href') for z in url]
    urls = ['http://hm.uz/'+a for a in Urls]
    
    titles = np.array(titles)
    prices = np.array(prices) 
    urls = np.array(urls)
    
    
    try:
        with open('data.csv', 'a', newline='', encoding='cp1251') as thething:
            writer = csv.writer(thething)
            for index,title in enumerate(titles):
                writer.writerow([datetime.now(),title,prices[index],URL,key,urls[index]])
        print("{}'s fineshed processing".format(key)) 
    except UnicodeEncodeError:
        continue
        
print(len(keywords)," product informations in HM.uz are exported to data.csv successfully!!!")

# %%
for key in keywords:
    if ' ' in key:
        key = key.replace(' ', '')
    else:
        key = key
        
    URL = "https://lebazar.uz/store/korzinka-uz-7/shedevr-78/search/result/products?searchKey={}".format(key)
    page = requests.get(URL, headers=headers)
    soup = BeautifulSoup(page.content,'html.parser')
    
    title1 = soup.find_all(attrs={"product-title"})
    price1 = soup.find_all(attrs={"product__price clearfix"})

    titles = [x.get_text() for x in title1]
    prices = [y.get_text() for y in price1]
    
    
    try:
        with open('data.csv', 'a', newline='', encoding='cp1251') as thething:
            writer = csv.writer(thething)
            for index,title in enumerate(titles):
                writer.writerow([datetime.now(),title,prices[index],URL,key," "])
        print("{}'s fineshed processing".format(key)) 
    except UnicodeEncodeError:
        continue

print(len(keywords)," product informations in LEBAZAR are exported to data.csv successfully!!!")
